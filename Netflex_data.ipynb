# %%
# loading data 
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()# head() function show firts 5 row of the dataset
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %% [markdown]
# ### Description of the dataframe

# %%
# tail() function shows last 5 rows of the dataset
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 8802  20-Nov-19          2007      R    158 min
# 8803   1-Jul-19          2018  TV-Y7  2 Seasons
# 8804   1-Nov-19          2009      R     88 min
# ...

# %%
# shape shows the number of columns and rows in the dataset 
df.shape
# Out:
# (8807, 12)

# %%
# this shows total elements in the dataset 
df.size
# Out:
# 105684

# %%
# column names 
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# datatypes of each column
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# summary of dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### Checking if there any duplicates and dealing with them

# %%
# checking duplicated
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Checking null values and dealing with them

# %%
# checking null values
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# showing null value in heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# for the Kota Factory what is show ID  and it's from which country 
df[df['title'].isin(['Kota Factory'])]
# Out:
#   show_id     type         title director  \
# 4      s5  TV Show  Kota Factory      NaN
#
#                                                 cast country date_added  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India  24-Sep-21
#
#    release_year rating   duration  \
# 4          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Task One

# %%
# when the House of cards released  
df[df['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      date_added  release_year rating   duration                listed_in  \
# 1059  14-Apr-21          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# #### to answer the above two questions one can use isin() or str.contains() function

# %%
df[df['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      date_added  release_year rating   duration                listed_in  \
# 1059  14-Apr-21          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Task Two

# %% [markdown]
# #### in which year highest  number of movies and TV shows were released

# %%
df['date_added']=pd.to_datetime(df['date_added'], errors='coerce')
# Out:
# C:\Users\abdir\AppData\Local\Temp\ipykernel_20864\2665177486.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date_added']=pd.to_datetime(df['date_added'], errors='coerce')

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
df['date_added'].dt.year.value_counts()
# Out:
# date_added
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
# showing in bargraph
df['date_added'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='date_added'>

# %% [markdown]
# ### Task Three

# %% [markdown]
# #### how many movies and TV shows are in the dataset

# %%
df.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# ### Task Four

# %% [markdown]
# #### All movies that were released in 2015

# %%
df[(df['type']=='Movie') & (df['release_year']==2015)]
# Out:
#      show_id   type                  title           director  \
# 116     s117  Movie                 Dhanak    Nagesh Kukunoor
# 133     s134  Movie                Chappie     Neill Blomkamp
# 141     s142  Movie             Extraction   Steven C. Miller
# 173     s174  Movie  Snervous Tyler Oakley           Amy Rice
# 257     s258  Movie       O Kadhal Kanmani        Mani Ratnam
# ...      ...    ...                    ...                ...
# 8779   s8780  Movie          Yes or No 2.5  Kirati Nakintanon
# 8784   s8785  Movie   Yoko and His Friends                NaN
# 8788   s8789  Movie           You Carry Me         Ivona Juka
# 8801   s8802  Movie                Zinzana    Majid Al Ansari
# 8806   s8807  Movie                 Zubaan        Mozez Singh
#
#                                                    cast  \
# 116   Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...
# 133   Sharlto Copley, Hugh Jackman, Sigourney Weaver...
# ...

# %% [markdown]
# #### Show only titles of movies that were released in India

# %%
df[(df['type']=='Movie') & (df["country"]=='India')]['title']
# Out:
# 24                      Jeans
# 105          Angamaly Diaries
# 114                    Anjaam
# 116                    Dhanak
# 118                   Gurgaon
#                 ...
# 8772    Yamla Pagla Deewana 2
# 8773      Yanda Kartavya Aahe
# 8798                 Zed Plus
# 8799                    Zenda
# 8806                   Zubaan
# Name: title, Length: 893, dtype: object

# %% [markdown]
# #### Show TV shows that were released in South Africa

# %%
df[(df["type"]=="TV Show")& (df['country'].isin(['Nigeri','South Africa']))]
# Out:
#      show_id     type                  title director  \
# 1         s2  TV Show          Blood & Water      NaN
# 1514   s1515  TV Show           Diamond City      NaN
# 1535   s1536  TV Show  How To Ruin Christmas      NaN
# 1593   s1594  TV Show       Kings of Jo'Burg      NaN
# 2611   s2612  TV Show               Tjovitjo      NaN
# 2870   s2871  TV Show             Queen Sono      NaN
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1514  Noxee Maqashalala, Angela Sithole, Nambitha Be...  South Africa
# 1535                                                NaN  South Africa
# 1593  Shona Ferguson, Zolisa Xaluva, Tsholofelo Mats...  South Africa
# 2611  Warren Masemola, Nobulali Dangazele, Rapulana ...  South Africa
# 2870  Pearl Thusi, Vuyo Dabula, Loyiso Madinga, Kate...  South Africa
#
#      date_added  release_year rating   duration  \
# ...

# %% [markdown]
# ### show movies that were released in south africa and nigeria

# %%
df[(df['type']=='Movie') & (df['country']=='South Africa')&(df['country']=='Nigeria')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# ### Task Five

# %% [markdown]
# #### Show top 10 directors who gave highest number of tv shows and movies to netflix

# %%
# counties for each director 
df['director'].value_counts()
# Out:
# director
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: count, Length: 4528, dtype: int64

# %%
# to get top 10 use head(10) function 
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
# ### show all records were type is movie and listed_in is comedies and country is united kingdom

# %%
df[(df['type'] == 'Movie') & (df['listed_in'] == 'Comedies') & (df['country'] == 'United Kingdom')]
# Out:
#      show_id   type                                              title  \
# 3332   s3333  Movie                                 Christmas Survival
# 4544   s4545  Movie   Monty Python Live (Mostly): One Down, Five to Go
# 4547   s4548  Movie           Monty Python: Live at The Hollywood Bowl
# 4554   s4555  Movie  Parrot Sketch Not Included: Twenty Years of Mo...
# 6576   s6577  Movie                Dead in a Week (Or Your Money Back)
# 6779   s6780  Movie                                  For Love or Money
# 8201   s8202  Movie                            The Bad Education Movie
# 8536   s8537  Movie                                  The Trip to Spain
#
#                            director  \
# 3332                  James Dearden
# 4544                      Eric Idle
# 4547  Terry Hughes, Ian MacNaughton
# 4554                Ian MacNaughton
# 6576                    Tom Edmunds
# 6779                    Mark Murphy
# 8201                 Elliot Hegarty
# ...

# %% [markdown]
# ### Task six

# %% [markdown]
# #### in how many movies/ Tv show Tom Cruise was cast

# %% [markdown]
# ### drop null values

# %%
df1=df.dropna()
df1.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 8                                      United Kingdom 2021-09-24
# ...

# %%
df1[df1['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      date_added  release_year rating duration                   listed_in  \
# 341  2021-08-01          1999      R  189 min  Dramas, Independent Movies
# 1254 2021-03-01          1988      R  134 min      Classic Movies, Dramas
#
#                                             description
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...

# %% [markdown]
# ### what are different rating in netflix

# %%
# how many ratings present in dataset
df['rating'].nunique()
# Out:
# 17

# %%
# list of different ratings 
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### how many movies got PG ratings in Canada

# %%
df[(df['type']=='Movie') & (df['rating']=='PG') & (df['country']=='Canada')]
# Out:
#      show_id   type                               title           director  \
# 1651   s1652  Movie  The Christmas Chronicles: Part Two     Chris Columbus
# 1753   s1754  Movie        Elliot the Littlest Reindeer  Jennifer Westcott
# 4390   s4391  Movie           Christmas Wedding Planner     Justin G. Dyck
# 4557   s4558  Movie                     A Witches' Ball     Justin G. Dyck
# 4891   s4892  Movie                  My Perfect Romance     Justin G. Dyck
# 5199   s5200  Movie            Pup Star: Better 2Gether       Robert Vince
# 6534   s6535  Movie         Cop and a Half: New Recruit      Jon Rosenbaum
# 7486   s7487  Movie                           Monkey Up       Robert Vince
#
#                                                    cast country date_added  \
# 1651  Kurt Russell, Goldie Hawn, Darby Camp, Jahzir ...  Canada 2020-11-25
# 1753  Josh Hutcherson, Samantha Bee, Martin Short, M...  Canada 2020-11-01
# ...

# %%
df[(df['type']=='Movie') & (df['rating']=='PG') & (df['country']=='Canada')].shape
# Out:
# (8, 12)
